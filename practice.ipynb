# %% [markdown]
# # Welcome to the Practice Session
#
# ## For this session,  we are going to work on creating branches, pull request and commiting changes.
#
# ### We will also learn how to merge pull requests.
#
# ### Have a Great session, feel free to ask any questions you may have.

# %%
from IPython.display import Image, display

display(Image(filename = r"C:\Users\nanay\Pictures\Screenshots\Screenshot 2024-09-11 140153.png"))

# %%
''' Edit is the name of the branch that we created yeaterday,thus we are working from the branch and not the default '''
# Out:
# ' Edit is the name of the branch that we created yeaterday,thus we are working from the branch and not the default '
